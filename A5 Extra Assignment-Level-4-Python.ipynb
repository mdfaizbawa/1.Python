# %%
# list out the items in the list

# %%
field=["Machine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
def Subfields():
  for sub in field:
    print(sub)

print("sub-fields in AI are:")
Subfields()
# Out:
# sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Create a function that checks whether the given number is Odd or Even

# %%
num=int(input("Enter a number:"))
def OddEven():
  if((num%2)==1):
    print(num,"is odd number")
    msg="Number is odd number"
  else:
    print(num,"is Even number")
    msg="Number is Even number"
  return(msg)
OddEven()
# Out:
# Enter a number:52452
# 52452 is Even number
# 'Number is Even number'

# %%
52# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
def Eligible():
  gender=input("Your Gender:")
  age=int(input("Your Age:"))
  if(gender=="Male" and age>21):
    print("ELIGIBLE")
  elif(gender=="Female" and age>18):
    print("ELIGIBLE")
  else:
    print("NOT ELIGIBLE")

Eligible()
# Out:
# Your Gender:Male
# Your Age:20
# NOT ELIGIBLE

# %%
def pecentage():
  sub1=int(input("Subject1="))
  sub2=int(input("Subject2="))
  sub3=int(input("Subject3="))
  sub4=int(input("Subject4="))
  sub5=int(input("Subject5="))
  total=sub1+sub2+sub3+sub4+sub5
  print("Total=",total)
  per=float(total)*100/500
  print("Percentage:",per)

# %%
pecentage()
# Out:
# Subject1=98
# Subject2=87
# Subject3=95
# Subject4=95
# Subject5=93
# Total= 468
# Percentage: 93.6

# %%
def triangle():
  Height=int(input("Height:"))
  Breadth=int(input("Breadth:"))
  print("Area formula:(Height*Breadth)/2")
  Area=((Height*Breadth)/2)
  print("Area of Triangle:",Area)
  Height1=int(input("Height1:"))
  Height2=int(input("Height2:"))
  Breadth1=int(input("Breadth:"))
  print("Perimeter formula:Height1+Height2+Breadth")
  perimeter=(Height1+Height2+Breadth1)
  print("Permeter of Triangle:",perimeter)

# %%
triangle()
# Out:
# Height:32
# Breadth:34
# Area formula:(Height*Breadth)/2
# Area of Triangle: 544.0
# Height1:2
# Height2:4
# Breadth:4
# Perimeter formula:Height1+Height2+Breadth
# Permeter of Triangle: 10
