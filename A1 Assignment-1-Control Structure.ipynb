# %%
print("Welocme to Assignment")
# Out:
# Welocme to Assignment

# %%
Num1=10
Num2=30
Add=Num1+Num2
print("Num1=",Num1)
print("Num2=",Num2)
print("Add=",Num1+Num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#Body Mass Index

# %%
BMI=int(input("Enter the BMI Index:"))
if(BMI<18.4):
  print("Underweight")
elif(BMI<24.9):
  print("Normal")
elif(BMI<39.9):
  print("Overweight")
else:
  print("Obese")
# Out:
# Enter the BMI Index:34
# Overweight
